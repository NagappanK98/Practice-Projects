# %% [markdown]
# # Mushroom Project

# %% [markdown]
# Here we are going to analyze whether the mushrooms are edible or poisonous

# %% [markdown]
# # Importing required Libraries

# %%
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# # Loading the Dataset

# %%
import pandas as pd
df = pd.read_csv("Mushroom.csv")         # mapped the column names as given in the dataset description
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %% [markdown]
# # Data Preparation

# %%
df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
# converting the categorical data to numerics using label encoder

from sklearn.preprocessing import LabelEncoder


labelencoder=LabelEncoder()
for i in df.columns:
    df[i] = labelencoder.fit_transform(df[i])

# %%
df.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %% [markdown]
# Here we can see there are some null values in the entire dataset
#
# Mean and median are also dont have much difference.

# %%
df=df.drop(["veil-type"],axis=1)         # removing since its 0

# %%
import matplotlib.pyplot as plt


plt.figure()
pd.Series(df['class']).value_counts().sort_index().plot(kind = 'bar')
plt.ylabel("Count")
plt.xlabel("class")
plt.title('Total no of poisonous(1) and edible(0) mushrooms');

# %%
import seaborn as sns

plt.figure(figsize=(18,16))
sns.heatmap(df.corr(),linewidths=.1, annot=True)

# %% [markdown]
# Here we observe that gill-color is negatively correlated

# %%
df[['class', 'gill-color']].groupby(['gill-color'], as_index=False).mean().sort_values(by='class', ascending=False)
# Out:
#     gill-color     class
# 0            0  1.000000
# 8            8  1.000000
# 3            3  0.721311
# 2            2  0.670213
# 7            7  0.428954
# 11          11  0.255814
# 10          10  0.204659
# 4            4  0.156863
# 5            5  0.106870
# 9            9  0.097561
# 1            1  0.000000
# 6            6  0.000000

# %%
new_var=df[['class', 'gill-color']]
new_var=new_var[new_var['gill-color']<=3.5]
sns.factorplot('class', col='gill-color', data=new_var, kind='count', size=2.5, aspect=.8, col_wrap=4);

# %%
new_var=df[['class', 'gill-color']]
new_var=new_var[new_var['gill-color']>3.5]

sns.factorplot('class', col='gill-color', data=new_var, kind='count', size=2.5, aspect=.8, col_wrap=4);

# %% [markdown]
# # Machine Learning Model

# %%
X=df.drop(['class'], axis=1)
Y=df['class']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test,Y_train,Y_test = train_test_split(X,Y, test_size = 0.1)

# %% [markdown]
# # Decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier


a = DecisionTreeClassifier()
b = a.fit(X_train, Y_train)

# %%
import numpy as np

features_list = X.columns.values
feature_importance = a.feature_importances_
sorted_idx = np.argsort(feature_importance)

plt.figure(figsize=(5,7))
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), features_list[sorted_idx])
plt.xlabel('Importance')
plt.title('Feature importances')
plt.draw()
plt.show()

# %%
y_pred=a.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_curve, auc, roc_curve


print("Decision Tree Classifier result is", classification_report(Y_test, y_pred))
# Out:
# Decision Tree Classifier result is               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       415
#            1       1.00      1.00      1.00       398
#
#     accuracy                           1.00       813
#    macro avg       1.00      1.00      1.00       813
# weighted avg       1.00      1.00      1.00       813

# %%
cfm=confusion_matrix(Y_test, y_pred)

sns.heatmap(cfm, annot = True,  linewidths=.5, cbar =None)
plt.title('Decision Tree Classifier confusion matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label');

# %% [markdown]
# From this we can see decision tree classifier provides 100% accuracy

# %% [markdown]
# # Gaussian Naive Bayes (GaussianNB)

# %%
from sklearn.naive_bayes import GaussianNB

c = GaussianNB()
d = c.fit(X_train, Y_train)

# %%
y_pred_GNB=c.predict(X_test)

# %%
cfm=confusion_matrix(Y_test, y_pred_GNB)

# %%
sns.heatmap(cfm, annot = True,  linewidths=.5, cbar =None)
plt.title('Gaussian Naive Bayes confusion matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 15.0, 'Predicted label')

# %%
print("Test data using Gaussian Naive Bayes method \n", classification_report(Y_test, y_pred_GNB))
# Out:
# Test data using Gaussian Naive Bayes method
#                precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91       415
#            1       0.90      0.92      0.91       398
#
#     accuracy                           0.91       813
#    macro avg       0.91      0.91      0.91       813
# weighted avg       0.91      0.91      0.91       813
